# %%
import prettymaps

dilate = 0  # Define dilate if not defined previously
plot = prettymaps.plot(
    'Grad, Split, Grad Split, Croatia',
    circle=False,
    radius=2500,
    layers={
        "streets": {
            "width": {
                "motorway": 5,
                "trunk": 5,
                "primary": 4.5,
                "secondary": 4,
                "tertiary": 3.5,
                "cycleway": 3.5,
                "residential": 3,
                "service": 2,
                "unclassified": 2,
                "pedestrian": 2,
                "footway": 1,
            },
            "circle": False,
            "dilate": dilate
        },
        "building": {
            "tags": {
                "building": True,
                "landuse": "construction"
            },
            "union": True,
            "circle": False,
            "dilate": dilate
        },
        "water": {
            "tags": {
                "natural": ["water", "bay","sea","coastline","strait" ]
            },
            "circle": False,
            "dilate": dilate,
            "include": ["Adriatic Sea"]  # Add "Adriatic Sea" to include it specifically
        },
        "forest": {
            "tags": {
                "landuse": "forest"
            },
            "circle": False,
            "dilate": dilate
        },
        "green": {
            "tags": {
                "landuse": ["grass", "orchard"],
                "natural": ["island", "wood"],
                "leisure": "park"
            },
            "circle": False,
            "dilate": dilate
        },
        "beach": {
            "tags": {
                "natural": "beach"
            },
            "circle": False,
            "dilate": dilate
        },
        "parking": {
            "tags": {
                "amenity": "parking",
                "highway": "pedestrian",
                "man_made": "pier"
            },
            "circle": False
        }
    },
    style={
        'perimeter': {'fill': False, 'lw': 0, 'zorder': 0},
        'background': {'fc': '#F2F4CB', 'ec': '#dadbc1', 'hatch': 'ooo...', 'zorder': -1},
        'green': {'fc': '#8BB174', 'ec': '#2F3737', 'hatch_c': '#A7C497', 'hatch': 'ooo...', 'lw': 1, 'zorder': 1},
        'forest': {'fc': '#64B96A', 'ec': '#2F3737', 'lw': 1, 'zorder': 2},
        'water': {'fc': '#a8e1e6', 'ec': '#2F3737', 'hatch': 'ooo...', 'hatch_c': '#9bc3d4', 'lw': 1, 'zorder': 3},
        'beach': {'fc': '#FCE19C', 'ec': '#2F3737', 'hatch_c': '#d4d196', 'hatch': 'ooo...', 'lw': 1, 'zorder': 3},
        'parking': {'fc':'#41393E', 'ec': '#2F3737', 'lw': 1, 'zorder': 3},
        'streets': {'fc': '#2F3737', 'ec': '#475657', 'alpha': 1, 'lw': 0, 'zorder': 4},
        'building': {'fc':'#807182', 'ec': '#2F3737', 'lw': .5, 'zorder': 5},
    }
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import prettymaps
#       3 dilate = 0  # Define dilate if not defined previously
#       4 plot = prettymaps.plot(
#       5     'Grad, Split, Grad Split, Croatia',
#       6     circle=False,
#    (...)
#      85     }
#      86 )
#
# ModuleNotFoundError: No module named 'prettymaps'
